# %%
print("Hello World")
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/User/Documents/GitHub/Python-Vitaliy/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
